# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# %%
# Your code goes here
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
df1 = pd.read_csv(url)
display(df1)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
df2 = pd.read_csv(url)
display(df2)
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
df3 = pd.read_csv(url)
display(df3)
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df3
df3.rename(columns= {"State" : "ST", 'Gender': 'GENDER'}, inplace=True)
# the 3rd df had state and gender differnt written. for me to apply the function to all the df was easier like this.

# %%
df = pd.concat([df1, df2, df3], axis=0)
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
from gf_functions import cleaning

cleaning(df)
display(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9134 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9134 non-null   object
#  1   st                         9134 non-null   object
#  2   gender                     9012 non-null   object
#  3   education                  9134 non-null   object
#  4   customer_lifetime_value    9127 non-null   object
#  5   income                     9134 non-null   float64
#  6   monthly_premium_auto       9134 non-null   float64
#  7   number_of_open_complaints  9134 non-null   object
#  8   policy_type                9134 non-null   object
#  9   vehicle_class              9134 non-null   object
#  10  total_claim_amount         9134 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 856.3+ KB
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
# ...

# %%
df.head()
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
# Cleaning code from the last lab:

df.rename(columns= {"st" : "state"}, inplace=True)
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized, for example, to "M" and "F".*
print(df.gender.unique())
df.gender = df.gender.replace({'F': 'F', 'M': 'M', 'Femal': 'F', 'Male': 'M', 'female': 'F', 'male': 'M'})
# Out:
# [nan 'F' 'M' 'Femal' 'Male' 'female']

# %%
display(df)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# - *State abbreviations be can replaced with its full name, for example "AZ": "Arizona", "Cali": "California", "WA": "Washington"*
print(df.state.unique())
df.state = df.state.replace({"AZ": "Arizona", "Cali": "California", "WA": "Washington"})
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA'
#  nan]

# %%
# - *In education, "Bachelors" could be replaced by "Bachelor"*
print(df.education.unique())
df.education = df.education.replace({"Bachelors": "Bachelor"})
print(df.education.unique())
# Out:
# ['Master' 'Bachelor' 'High School or Below' 'College' 'Bachelors' 'Doctor'
#  nan]
# ['Master' 'Bachelor' 'High School or Below' 'College' 'Doctor' nan]

# %%
df.customer_lifetime_value = df.customer_lifetime_value.str.rstrip('%').astype('float')
print(df.customer_lifetime_value)
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065           NaN
# 7066           NaN
# 7067           NaN
# 7068           NaN
# 7069           NaN
# Name: customer_lifetime_value, Length: 12074, dtype: float64

# %%
# - *In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"*
print(df.vehicle_class.unique())
df.vehicle_class = df.vehicle_class.replace({"Sports Car": "Luxury", "Luxury SUV": "Luxury", "Luxury Car": "Luxury"})
# Out:
# ['Four-Door Car' 'Two-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car' nan]

# %%
# *Number of open complaints has an incorrect format. Look at the different values it takes with `unique()` and take the middle value. 
# As an example, 1/5/00 should be 5. Number of open complaints is a string - remember you can use `split()` to deal with it and take the number you need. 
# Finally, since it should be numeric, cast the column to be in its proper type.*

df.number_of_open_complaints = df.number_of_open_complaints.str.split("/").str[1].astype(float)
# df.number_of_open_complaints = df.number_of_open_complaints.astype(float)
df.number_of_open_complaints.unique()
# Out:
# array([ 0.,  2.,  1.,  3.,  5.,  4., nan])

# %%
# Identify any columns with null or missing values. Identify how many null values each column has. You can use the `isnull()` function in pandas to find columns with null values.
null_counts = df.isnull().sum()
display(null_counts)
# Out:
# customer                      2937
# state                         2937
# gender                        3059
# education                     2937
# customer_lifetime_value      10014
# income                        2937
# monthly_premium_auto          2937
# number_of_open_complaints    10007
# policy_type                   2937
# vehicle_class                 2937
# total_claim_amount            2937
# dtype: int64

# %%
df = df.dropna(how="all")  # Removes rows with null values

# %%
df.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             2.060000e+03   9137.000000           9137.000000
# mean              7.799463e+05  37828.820291            110.391266
# std               6.329809e+05  30358.716159            581.376032
# min               2.004351e+05      0.000000             61.000000
# 25%               3.978076e+05      0.000000             68.000000
# 50%               5.720275e+05  34244.000000             83.000000
# 75%               8.819019e+05  62447.000000            109.000000
# max               5.816655e+06  99981.000000          35354.000000
#
#        number_of_open_complaints  total_claim_amount
# count                2067.000000         9137.000000
# mean                    0.381713          430.527140
# std                     0.886007          289.582968
# min                     0.000000            0.099007
# 25%                     0.000000          266.996814
# ...

# %%
df.gender.unique()
df.gender = df.gender.fillna('U')
# Out:
# /var/folders/tx/45hhw1yn48jfdqn2hmnhbhvw0000gn/T/ipykernel_68733/1313029186.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.gender = df.gender.fillna('U')

# %%
null_counts = df.isnull().sum()
display(null_counts)
# Out:
# customer                        0
# state                           0
# gender                          0
# education                       0
# customer_lifetime_value      7077
# income                          0
# monthly_premium_auto            0
# number_of_open_complaints    7070
# policy_type                     0
# vehicle_class                   0
# total_claim_amount              0
# dtype: int64

# %%
df.customer_lifetime_value.unique()
# Out:
# array([       nan,  697953.59, 1288743.17, ...,  568964.41,  368672.38,
#         399258.39])

# %%
df.customer_lifetime_value = df.customer_lifetime_value.fillna(df.customer_lifetime_value.mean())
# Out:
# /var/folders/tx/45hhw1yn48jfdqn2hmnhbhvw0000gn/T/ipykernel_68733/4053169491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.customer_lifetime_value = df.customer_lifetime_value.fillna(df.customer_lifetime_value.mean())

# %%
df.loc[:, 'customer_lifetime_value'] = df['customer_lifetime_value'].fillna(df['customer_lifetime_value'].mean())

# %%
df.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             9.137000e+03   9137.000000           9137.000000
# mean              7.799463e+05  37828.820291            110.391266
# std               3.004974e+05  30358.716159            581.376032
# min               2.004351e+05      0.000000             61.000000
# 25%               7.799463e+05      0.000000             68.000000
# 50%               7.799463e+05  34244.000000             83.000000
# 75%               7.799463e+05  62447.000000            109.000000
# max               5.816655e+06  99981.000000          35354.000000
#
#        number_of_open_complaints  total_claim_amount
# count                2067.000000         9137.000000
# mean                    0.381713          430.527140
# std                     0.886007          289.582968
# min                     0.000000            0.099007
# 25%                     0.000000          266.996814
# ...

# %%
# Your code here
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 9137, dtype: bool

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df4 = pd.read_csv(url)
display(df4)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
cleaning(df4)
display(df4.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
df4.isnull().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# month                            0
# ...

# %%
df4.customer.unique()
# Out:
# array(['DK49336', 'KX64629', 'LZ68649', ..., 'KX53892', 'TL39050',
#        'WA60547'], dtype=object)

# %%
df4.customer_lifetime_value.unique()
# Out:
# array([ 4809.21696 ,  2228.525238, 14947.9173  , ...,  5259.444853,
#        23893.3041  , 11971.97765 ])

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
# Your code goes here
df4.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
pivot_df4 = df4.pivot_table(index='sales_channel', values='total_claim_amount', aggfunc='sum')
display(pivot_df4)
# Out:
#                total_claim_amount
# sales_channel
# Agent                1.810227e+06
# Branch               1.301204e+06
# Call Center          9.266008e+05
# Web                  7.066000e+05

# %%
rounded_pivot_table = pivot_df4.round(decimals=2)
display(rounded_pivot_table)
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %% [markdown]
# ### Insights
#
# The pivot table shows that the sales channel 'Agent' brought in the most sales in terms of total revenue, followed by 'Branch', 'Call Center', and 'Web'. This indicates that the 'Agent' channel is the most effective in generating revenue, while the 'Web' channel is the least effective.

# %%
df4.pivot(index='sales_channel', columns='education', values='total_claim_amount')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df4.pivot(index='sales_channel', columns='education', values='total_claim_amount')
#
# File /opt/anaconda3/envs/datasci_env/lib/python3.8/site-packages/pandas/core/frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File /opt/anaconda3/envs/datasci_env/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:557, in pivot(data, columns, index, values)
#     553         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
# pivot2_df4 = df4.pivot_table(index='sales_channel', values='total_claim_amount', aggfunc='sum')

df4.pivot_table(index='gender', columns='education', values='customer_lifetime_value', aggfunc='mean')
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          7874.269478  7748.823325  7328.508916           8675.220201
# M          7703.601675  8052.459288  7415.333638           8149.687783
#
# education       Master
# gender
# F          8157.053154
# M          8168.832659

# %% [markdown]
# #### Insights:
# **Higher Average CLV for Females in 'High School or Below'**: It appears that females with a high school education or below have the highest average CLV among the groups considered.
#
# **Variation Across Education Levels:** The average CLV varies across education levels, with certain levels such as 'Doctor' and 'College' showing small different patterns between genders.
# Comparative Insights: Males with a College degree have a higher average CLV compared to females, whereas for other education levels, particularly at the 'High School or Below', females have a notably higher CLV.
# The most even value is in 'Master' where the numbers in male is just above female.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
